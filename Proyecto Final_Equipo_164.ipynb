# %% [markdown]
# Ciencia y Analítica de Datos
# Proyecto Final
#
# Adriana Fernanda Jiménez Avalos A01087695
# Luis Alfredo Negron Naldos A01793865

# %% [markdown]
# ***Avance 1
# Conjunto de Datos de internet***
#
#
# -**El nombre que caracteriza el conjunto de datos:**.
# Bank Marketing Data Set
#
# -*La organización que lo generó*. UCI - Machine Learning Repository
# https://archive.ics.uci.edu/ml/datasets/bank+marketing
#
#
# -**Describe el conjunto de datos*. ¿Qué datos contiene?**
#
# Esta base de datos presenta los datos están relacionados con las campañas de marketing directo de una institución bancaria portuguesa. Las campañas de marketing se basaban en llamadas telefónicas.
#
# A menudo, se requería más de un contacto con el mismo cliente, para acceder a si el producto (depósito bancario a plazo) sería ('sí') o no ('no') suscrito, esto ayuda a las empresas a enfocar mejor sus recursos.
#
# Detalle de las Variables
#
# Datos de los Clientes:
# - age (numeric)
# - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# - default: has credit in default? (categorical: 'no','yes','unknown')
# - housing: has housing loan? (categorical: 'no','yes','unknown')
# - loan: has personal loan? (categorical: 'no','yes','unknown')
#
# Datos relativos al último contacto en la campaña:
# - contact: contact communication type (categorical: 'cellular','telephone')
# - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# Otros Atributos:
# - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# - previous: number of contacts performed before this campaign and for this client (numeric)
# - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
# Datos de Contexto Socio Económico
# - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# - cons.price.idx: consumer price index - monthly indicator (numeric)
# - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# - euribor3m: euribor 3 month rate - daily indicator (numeric)
# - nr.employed: number of employees - quarterly indicator (numeric)
#
# Variable Objetivo:
#
# - Y - has the client subscribed a term deposit? (binary: 'yes','no')
#
# **¿Cuáles son algunas de las preguntas de investigación que podría responder con estos datos? Enumere al menos OCHO (no responda las preguntas)**
#
# 1. ¿ Cuál es la probabilidad de exito de este tipo de camapaña ?
# 2. ¿Qué variable tiene mayor efecto en el exito de este tipo de campaña?
# 3. ¿Qué relación existe entre las variables de la base de datos y la variable objetivo?
# 4. Si solo utilizo las variables del cliente ¿Qué nivel de predicción puedo obtener?
# 5. Si solo utilizo las variables de último contacto ¿Qué nivel de predicción puedo obtener?
# 6. Si solo utilizo los atributos de contexto (otros atributos) ¿Qué nivel de predicción puedo obtener?
# 7. Es posible generar campañas para segmentos diferentes de cliente o esto no genera diferencia en el resultado de la misma?
# 8. A cuantas variables puedo reducir un modelo de predicción para mejorar el resultado de las campañas de marketing directo?
#
#
# -¿Qué actor (empresa, sector de la sociedad, organismo descentralizado, gobierno, etc.) estaría interesado en las preguntas mencionadas que identificó?
# Los negocios interesados en esta informacion podrian ser empresas de servicios que venden productos financieros o agencias de marketing en general que utilizan el marketing directo como formo de promocionar y vender sus productos.

# %% [markdown]
# ***Avance 2****
# La metodología CRISP-DM sirve como base del proceso de ciencia de datos, esta es la metodología que utilizaremos para nuestro proyecto.
#
# La metodología CRISP se identifica por tener 6 pasos estándares. Estos incluyen entender el negocio, entender los datos de información, preparación de datos, modelado de datos, evaluación e implementación. La metodología CRISP puede tener un enfoque Agile o Waterfall lo cual brinda la flexibilidad del uso de esta metodología.
#
# Para los primeros pasos que realizaremos como todo buen proyecto se inicia al momento de entender bien la información de negocio en este caso el problema que presentaremos. Este es relacionado con la tasa de existo de las campañas de marketign directo (MD). Es importante conocer el impacto que tiene el MD en los tipos de clientes, esfuero de ventas y otros características de contexto para mejorar los recursos asignados a este tipo de campañas.
#
#
# El segundo paso es entender los datos de información por analizar, que información se tiene, limpiar la información y filtrar datos que no se ocupen. El tercer paso es la preparación de datos, esto conlleva a cómo organizar los datos para modelado. El cuarto paso es modelado de datos, donde se debe identificar la técnica por aplicar. Las técnicas pueden ser de regresión, neural net entre otras. El quinto paso es evaluación, que es el modelo que mejor alinea con el objetivo del negocio. Y el último paso implementación el cual se enfoca en cómo dar la información a los clientes de interés. Este último paso también es importante agenda monitoreo y mantenimiento, reporte final y revisión del proyecto.

# %% [markdown]
# ![Captura de Pantalla 2022-09-26 a la(s) 22.34.12.png](data:image/png;base64,...)
